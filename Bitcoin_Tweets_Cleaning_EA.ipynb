# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %%
raw = pd.read_csv('Bitcoin_tweets_dataset_2.csv', lineterminator='\n')
raw.head()
# Out:
#        user_name   user_location  \
# 0        ChefSam  Sunshine State
# 1          Roy⚡️             NaN
# 2  Ethereum Yoda             NaN
# 3        Viction   Paris, France
# 4          Rosie          London
#
#                                     user_description         user_created  \
# 0  Culinarian | Hot Sauce Artisan | Kombucha Brew...  2011-03-23 03:50:13
# 1  Truth-seeking pleb 📚 • Science 🧪 • Nature 🌱☀️ ...  2022-01-30 17:41:41
# 2      UP or DOWN...\n.\n.\n.\n.\nPrice matters NOT.  2022-07-24 04:50:18
# 3  https://t.co/8M3rgdjwEe\n\n#bitcoin #blockchai...  2010-03-26 10:15:26
# 4  The flower language of jasmine is loyalty, res...  2013-02-16 09:57:56
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0            4680          2643             6232          False
# 1             770          1145             9166          False
# 2             576             1                0          False
# 3             236          1829             2195          False
# 4           12731            46              134          False
#
#                   date                                               text  \
# 0  2023-03-01 23:59:59  Which #bitcoin books should I think about read...
# 1  2023-03-01 23:59:47  @ThankGodForBTC I appreciate the message, but ...
# 2  2023-03-01 23:59:42  #Ethereum price update: \n\n#ETH $1664.02 USD\...
# 3  2023-03-01 23:59:36  CoinDashboard v3.0 is here\nAvailable on ios a...
# 4  2023-03-01 23:59:32  #Bitcoin Short Term Fractal (4H)💥\n\nIn lower ...
#
#                                             hashtags               source  \
# 0                                        ['bitcoin']   Twitter for iPhone
# 1                                        ['Bitcoin']   Twitter for iPhone
# 2  ['Ethereum', 'ETH', 'Bitcoin', 'BTC', 'altcoin...      Twitter Web App
# 3                                        ['Bitcoin']  Twitter for Android
# 4                                 ['Bitcoin', 'BTC']      Twitter Web App
#
#    is_retweet
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False

# %%
print("Data type : ", type(raw))
print("Data dims : ", raw.shape)
# Out:
# Data type :  <class 'pandas.core.frame.DataFrame'>
# Data dims :  (169820, 13)

# %% [markdown]
# # Cleaning
# #### Certain columns ( user_location, user_description, user_created) would not affect the content of the tweet as they just represent the user's information, and thus can be removed as they don't provide insight towards the tweet

# %%
clean = raw.copy()
clean.drop('user_location', inplace = True, axis = 1)
clean.drop('user_description', inplace = True, axis = 1)
clean.drop('user_created', inplace = True, axis = 1)
clean.head()
# Out:
#        user_name  user_followers  user_friends  user_favourites  \
# 0        ChefSam            4680          2643             6232
# 1          Roy⚡️             770          1145             9166
# 2  Ethereum Yoda             576             1                0
# 3        Viction             236          1829             2195
# 4          Rosie           12731            46              134
#
#    user_verified                 date  \
# 0          False  2023-03-01 23:59:59
# 1          False  2023-03-01 23:59:47
# 2          False  2023-03-01 23:59:42
# 3          False  2023-03-01 23:59:36
# 4          False  2023-03-01 23:59:32
#
#                                                 text  \
# 0  Which #bitcoin books should I think about read...
# 1  @ThankGodForBTC I appreciate the message, but ...
# 2  #Ethereum price update: \n\n#ETH $1664.02 USD\...
# 3  CoinDashboard v3.0 is here\nAvailable on ios a...
# 4  #Bitcoin Short Term Fractal (4H)💥\n\nIn lower ...
#
#                                             hashtags               source  \
# 0                                        ['bitcoin']   Twitter for iPhone
# 1                                        ['Bitcoin']   Twitter for iPhone
# 2  ['Ethereum', 'ETH', 'Bitcoin', 'BTC', 'altcoin...      Twitter Web App
# 3                                        ['Bitcoin']  Twitter for Android
# 4                                 ['Bitcoin', 'BTC']      Twitter Web App
#
#    is_retweet
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False

# %%
clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169820 entries, 0 to 169819
# Data columns (total 10 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   user_name        169819 non-null  object
#  1   user_followers   169820 non-null  int64
#  2   user_friends     169820 non-null  int64
#  3   user_favourites  169820 non-null  int64
#  4   user_verified    169820 non-null  bool
#  5   date             169820 non-null  object
#  6   text             169820 non-null  object
#  7   hashtags         169820 non-null  object
#  8   source           169820 non-null  object
#  9   is_retweet       169820 non-null  bool
# dtypes: bool(2), int64(3), object(5)
# memory usage: 10.7+ MB

# %%
print(clean[clean['user_name'].isna()])
# Out:
#        user_name  user_followers  user_friends  user_favourites  \
# 166818       NaN              10            10               13
#
#         user_verified                 date  \
# 166818          False  2023-03-04 19:45:37
#
#                                                      text        hashtags  \
# 166818  Opensea or blur Where best to start trading #N...  ['NFT', 'BTC']
#
#                  source  is_retweet
# 166818  Twitter Web App       False

# %% [markdown]
# #### user_name is not supposed to have null values, could be the result of an error. Fill in with a placeholder

# %%
clean['user_name'].fillna(value = "UNKNOWN_USER_placeholder", inplace = True)
clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169820 entries, 0 to 169819
# Data columns (total 10 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   user_name        169820 non-null  object
#  1   user_followers   169820 non-null  int64
#  2   user_friends     169820 non-null  int64
#  3   user_favourites  169820 non-null  int64
#  4   user_verified    169820 non-null  bool
#  5   date             169820 non-null  object
#  6   text             169820 non-null  object
#  7   hashtags         169820 non-null  object
#  8   source           169820 non-null  object
#  9   is_retweet       169820 non-null  bool
# dtypes: bool(2), int64(3), object(5)
# memory usage: 10.7+ MB

# %% [markdown]
# ## We will be using the VADER Package to provide further insight into the data
# #### VADER (Valence Aware Dictionary and sEntiment Reasoner) is a lexicon and rule-based sentiment analysis tool that is specifically attuned to sentiments expressed in social media. As such, it evaluates the text, and provide a score between -1.0(negative) and 1.0(positive). However, the text has to be modifed to remove certain characters that are not compatible wit VADER.

# %%
! pip install vaderSentiment
# Out:
# Requirement already satisfied: vaderSentiment in c:\users\arif1\anaconda3\lib\site-packages (3.3.2)
# Requirement already satisfied: requests in c:\users\arif1\anaconda3\lib\site-packages (from vaderSentiment) (2.28.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\arif1\anaconda3\lib\site-packages (from requests->vaderSentiment) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\arif1\anaconda3\lib\site-packages (from requests->vaderSentiment) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\arif1\anaconda3\lib\site-packages (from requests->vaderSentiment) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\arif1\anaconda3\lib\site-packages (from requests->vaderSentiment) (3.3)

# %%
import re
from tqdm import tnrange, tqdm_notebook, tqdm

for i,s in enumerate(tqdm(clean['text'],position=0, leave=True)):
    text = str(clean.loc[i, 'text'])
    text = text.replace("#", "")
    text = re.sub('https?://(?:[-\w.]|(?:%[\da-fA-F]{2}))+', '', text, flags=re.MULTILINE)
    text = re.sub('@\\w+ *', '', text, flags=re.MULTILINE)
    clean.loc[i, 'text'] = text
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 169820/169820 [00:13<00:00, 12804.19it/s]

# %%
clean.head()
# Out:
#        user_name  user_followers  user_friends  user_favourites  \
# 0        ChefSam            4680          2643             6232
# 1          Roy⚡️             770          1145             9166
# 2  Ethereum Yoda             576             1                0
# 3        Viction             236          1829             2195
# 4          Rosie           12731            46              134
#
#    user_verified                 date  \
# 0          False  2023-03-01 23:59:59
# 1          False  2023-03-01 23:59:47
# 2          False  2023-03-01 23:59:42
# 3          False  2023-03-01 23:59:36
# 4          False  2023-03-01 23:59:32
#
#                                                 text  \
# 0  Which bitcoin books should I think about readi...
# 1  I appreciate the message, but not a fan of the...
# 2  Ethereum price update: \n\nETH $1664.02 USD\nB...
# 3  CoinDashboard v3.0 is here\nAvailable on ios a...
# 4  Bitcoin Short Term Fractal (4H)💥\n\nIn lower t...
#
#                                             hashtags               source  \
# 0                                        ['bitcoin']   Twitter for iPhone
# 1                                        ['Bitcoin']   Twitter for iPhone
# 2  ['Ethereum', 'ETH', 'Bitcoin', 'BTC', 'altcoin...      Twitter Web App
# 3                                        ['Bitcoin']  Twitter for Android
# 4                                 ['Bitcoin', 'BTC']      Twitter Web App
#
#    is_retweet
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()
compound = []
for i,s in enumerate(tqdm(clean['text'],position=0, leave=True)):
    vs = analyzer.polarity_scores(str(s))
    compound.append(vs["compound"])
clean["sentiment_value"] = compound
clean.head(2)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 169820/169820 [00:19<00:00, 8513.88it/s]
#   user_name  user_followers  user_friends  user_favourites  user_verified  \
# 0   ChefSam            4680          2643             6232          False
# 1     Roy⚡️             770          1145             9166          False
#
#                   date                                               text  \
# 0  2023-03-01 23:59:59  Which bitcoin books should I think about readi...
# 1  2023-03-01 23:59:47  I appreciate the message, but not a fan of the...
#
#       hashtags              source  is_retweet  compound  sentiment_value
# 0  ['bitcoin']  Twitter for iPhone       False    0.0000           0.0000
# 1  ['Bitcoin']  Twitter for iPhone       False   -0.1513          -0.1513

# %% [markdown]
# ## Exporting cleaned and modifed csv

# %%
clean.to_csv('bitcoin_tweets', header=True, encoding='utf-8',index=False)
